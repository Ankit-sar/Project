# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('E:\\Data science santander')

# %%
os.getcwd()
# Out:
# 'E:\\Data science santander'

# %%
train_df=pd.read_csv('train.csv')
test_df=pd.read_csv('test.csv')

# %% [markdown]
# # Data exploration

# %%
print("dimensions of train data:",train_df.shape)
print("dimensions of test data:",test_df.shape)
# Out:
# dimensions of train data: (200000, 202)
# dimensions of test data: (200000, 201)

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 307.5+ MB

# %%
train_df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# 25%         5.254075       9.883175     -11.200350       4.767700
# 50%         6.825000      11.108250      -4.833150       5.385100
# 75%         8.324100      12.261125       0.924800       6.003000
# max        13.188300      16.671400      17.251600       8.447700
#
#                var_7          var_8  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean       16.545850       0.284162  ...       3.234440       7.438408
# std         3.418076       3.332634  ...       4.559922       3.023272
# min         5.349700     -10.505500  ...     -14.093300      -2.691700
# 25%        13.943800      -2.317800  ...      -0.058825       5.157400
# 50%        16.456800       0.393700  ...       3.203600       7.347750
# 75%        19.102900       2.937900  ...       6.406200       9.512525
# max        27.691800      10.151300  ...      18.440900      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.927839       3.331774      17.993784      -0.142088
# std         1.478423       3.992030       3.135162       1.429372
# min        -3.814500     -11.783400       8.694400      -5.261000
# 25%         0.889775       0.584600      15.629800      -1.170700
# 50%         1.901300       3.396350      17.957950      -0.172700
# 75%         2.949500       6.205800      20.396525       0.829600
# max         8.402400      18.281800      27.928800       4.272900
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.303335       8.908158      15.870720      -3.326537
# std         5.454369       0.921625       3.010945      10.438015
# min       -14.209600       5.960600       6.299300     -38.852800
# 25%        -1.946925       8.252800      13.829700     -11.208475
# 50%         2.408900       8.888200      15.934050      -2.819550
# 75%         6.556725       9.593300      18.064725       4.836800
# max        18.321500      12.000400      26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 201 entries, ID_code to var_199
# dtypes: float64(200), object(1)
# memory usage: 305.9+ MB

# %%
test_df.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# 25%         9.891075     -11.201400       4.772600      13.933900
# 50%        11.099750      -4.834100       5.391600      16.422700
# 75%        12.253400       0.942575       6.005800      19.094550
# max        16.037100      17.253700       8.302500      28.292800
#
#                var_8          var_9  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean        0.277135       7.569407  ...       3.189766       7.458269
# std         3.333375       1.231865  ...       4.551239       3.025189
# min        -9.956000       4.243300  ...     -14.093300      -2.407000
# 25%        -2.303900       6.623800  ...      -0.095000       5.166500
# 50%         0.372000       7.632000  ...       3.162400       7.379000
# 75%         2.930025       8.584825  ...       6.336475       9.531100
# max         9.665500      11.003600  ...      20.359000      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.925944       3.322016      17.996967      -0.133657
# std         1.479966       3.995599       3.140652       1.429678
# min        -3.340900     -11.413100       9.382800      -4.911900
# 25%         0.882975       0.587600      15.634775      -1.160700
# 50%         1.892600       3.428500      17.977600      -0.162000
# 75%         2.956000       6.174200      20.391725       0.837900
# max         8.005000      17.632600      27.947800       4.545400
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.290899       8.912428      15.869184      -3.246342
# std         5.446346       0.920904       3.008717      10.398589
# min       -13.944200       6.169600       6.584000     -39.457800
# 25%        -1.948600       8.260075      13.847275     -11.124000
# 50%         2.403600       8.892800      15.943400      -2.725950
# 75%         6.519800       9.595900      18.045200       4.935400
# max        15.920700      12.275800      26.538400      27.907400
#
# [8 rows x 200 columns]

# %% [markdown]
# .Standard Deviation in both train and test is quite significant.
# .Mean and other measures are close.

# %% [markdown]
# # Missing value analysis

# %%
#checking for missing values and data types in train data
value = []
for col in train_df.columns:
    dtype = str(train_df[col].dtype)
    value.append(dtype)
dt= pd.DataFrame(data=train_df.isnull().sum(),columns=['Missing'])
dt['dtypes']=value
np.transpose(dt)
# Out:
#         ID_code target    var_0    var_1    var_2    var_3    var_4    var_5  \
# Missing       0      0        0        0        0        0        0        0
# dtypes   object  int64  float64  float64  float64  float64  float64  float64
#
#            var_6    var_7  ...  var_190  var_191  var_192  var_193  var_194  \
# Missing        0        0  ...        0        0        0        0        0
# dtypes   float64  float64  ...  float64  float64  float64  float64  float64
#
#          var_195  var_196  var_197  var_198  var_199
# Missing        0        0        0        0        0
# dtypes   float64  float64  float64  float64  float64
#
# [2 rows x 202 columns]

# %%
#checking for missing values and data types in test data
value = []
for col in test_df.columns:
    dtype = str(test_df[col].dtype)
    value.append(dtype)
dt= pd.DataFrame(data=test_df.isnull().sum(),columns=['Missing'])
dt['dtypes']=value
np.transpose(dt)
# Out:
#         ID_code    var_0    var_1    var_2    var_3    var_4    var_5  \
# Missing       0        0        0        0        0        0        0
# dtypes   object  float64  float64  float64  float64  float64  float64
#
#            var_6    var_7    var_8  ...  var_190  var_191  var_192  var_193  \
# Missing        0        0        0  ...        0        0        0        0
# dtypes   float64  float64  float64  ...  float64  float64  float64  float64
#
#          var_194  var_195  var_196  var_197  var_198  var_199
# Missing        0        0        0        0        0        0
# dtypes   float64  float64  float64  float64  float64  float64
#
# [2 rows x 201 columns]

# %% [markdown]
# So, there is no missing data in both the train & test data
#
# Both the data set have 200000 observations while only train data has target variable (int64) remaining all other variables are stored as (float64)

# %% [markdown]
# # Exploratory data analysis

# %%
#checking the data distribution in target column
sns.set(style='whitegrid')
sns.countplot(train_df['target'], palette='Set2')
plt.title("Distribution in Target Variable ")
# Out:
# Text(0.5, 1.0, 'Distribution in Target Variable ')

# %%
print('There are {}% 1\'s in target variable'.format(100 * train_df['target'].value_counts()[1]/train_df.shape[0]))
print('& {}% 0\'s in target variable'.format(100 * train_df['target'].value_counts()[0]/train_df.shape[0]))
# Out:
# There are 10.049% 1's in target variable
# & 89.951% 0's in target variable

# %% [markdown]
# It is clear this is a unbalanced data set. we have to resample it in the later stage.

# %%
#defining a function for visualizing data distribution in variables
def plot_distribution(df, columns):
    sns.set()
    fig, ax= plt.subplots(10,10,figsize=(20,24))
    i = 0
    for col in columns:
        i += 1
        plt.subplot(10,10,i)
        sns.distplot(df[col])
        plt.xlabel(col, fontsize=9)
        plt.tick_params(axis='x', labelsize=6, pad=-7)
    plt.show()

# %%
#setting columns and viewing data
columns =train_df.columns.values[2:102] 
plot_distribution(train_df,columns)

# %%
#viewing data for remaining columns
columns=train_df.columns.values[102:]
plot_distribution(train_df,columns)

# %% [markdown]
# From the same function we can view the distribution of test set as well. from the above plots we can see that the data is well distributed though there were some exceptions here and there.

# %% [markdown]
# # Outlier analysis

# %%
def feature_boxplot(df, columns):
    sns.set(style='whitegrid')
    fig, ax = plt.subplots(10,10,figsize=(18,24))
    plt.title("Outliers")
    i=0
    for col in columns:
        i += 1
        plt.subplot(10,10,i)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=9)
        plt.tick_params(axis='x', labelsize=7, pad= -7)
    plt.show()

# %%
columns=train_df.columns.values[2:102]
feature_boxplot(train_df,columns)

# %%
columns=train_df.columns.values[102:]
feature_boxplot(train_df,columns)

# %%
#checking for outliers in test data set
columns = test_df.columns.values[2:102]
feature_boxplot(test_df,columns)

# %% [markdown]
# We the box plots we can see that almost all the variables have outliers so we have to get rid of them.
#
# #Finding the outliers in the data cols=train_df.columns.values[2:60] fig, ax = plt.subplots(figsize=(20,24)) sns.boxplot(data=train_df[cols],ax=ax) plt.title("Data Distribution") plt.show()

# %%
#Finding the outliers in the data 
cols=train_df.columns.values[2:60] 
fig,ax = plt.subplots(figsize=(20,24))
sns.boxplot(data=train_df[cols],ax=ax)
plt.title("Data Distribution") 
plt.show()

# %%
#creating columns list
cnames = train_df.drop(['target','ID_code'],axis=1).columns
cnames
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-39-9ed8e12dad2a> in <module>
#       1 #creating columns list
# ----> 2 cnames = train_df.drop(['target','ID_code'],axis=1).columns
#       3 cnames
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945             else:
#    3946                 new_axis = axis.drop(labels, errors=errors)
# -> 3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#    3949         # Case for non-unique axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3841         if columns is not None:
#    3842             frame = frame._reindex_columns(
# -> 3843                 columns, method, copy, level, fill_value, limit, tolerance
#    3844             )
#    3845
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3889             copy=copy,
#    3890             fill_value=fill_value,
# -> 3891             allow_dups=False,
#    3892         )
#    3893
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1355                             axis=0,
#    1356                             new_mgr_locs=mgr_locs,
# -> 1357                             fill_tuple=None,
#    1358                         )
#    1359                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1714             out = np.empty(out_shape, dtype=dtype, order="F")
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#    1718     func = _get_take_nd_function(
#
# MemoryError:

# %%
#copying df
df_train =train_df.copy()
df_test = test_df.copy()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-41-93a606a4d61a> in <module>
#       1 #copying df
# ----> 2 df_train =train_df.copy()
#       3 df_test = test_df.copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5994         dtype: object
#    5995         """
# -> 5996         data = self._data.copy(deep=deep)
#    5997         return self._constructor(data).__finalize__(self)
#    5998
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     770         values = self.values
#     771         if deep:
# --> 772             values = values.copy()
#     773         return self.make_block_same_class(values, ndim=self.ndim)
#     774
#
# MemoryError:

# %%
#detecting and deleting outliers from the  train data
for i in cnames:
    q75, q25 =np.percentile(train_df.loc[:,i],[75,25])
    iqr  = q75-q25
    min  = q25 - (iqr*1.5)
    max  = q75 + (iqr*1.5)
    train_df = train_df.drop(train_df[train_df.loc[:,i]<min].index) 
    train_df = train_df.drop(train_df[train_df.loc[:,i]>max].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4aaeefae0470> in <module>
#       1 #detecting and deleting outliers from the  train data
# ----> 2 for i in cnames:
#       3     q75, q25 =np.percentile(train_df.loc[:,i],[75,25])
#       4     iqr  = q75-q25
#       5     min  = q25 - (iqr*1.5)
#
# NameError: name 'cnames' is not defined

# %%
#checking the number of observations dropped
print("Total number of observations dropped in train set:",df_train.shape[0]-train_df.shape[0])
train_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-1546e01511f5> in <module>
#       1 #checking the number of observations dropped
# ----> 2 print("Total number of observations dropped in train set:",df_train.shape[0]-train_df.shape[0])
#       3 train_df.shape
#
# NameError: name 'df_train' is not defined

# %%
#detecting and deleting outliers from the  test data
for i in cnames:
    q75, q25 =np.percentile(test_df.loc[:,i],[75,25])
    iqr  = q75-q25
    min  = q25 - (iqr*1.5)
    max  = q75 + (iqr*1.5)
    test_df = test_df.drop(test_df[test_df.loc[:,i]<min].index) 
    test_df = test_df.drop(test_df[test_df.loc[:,i]>max].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-99e59d1c1924> in <module>
#       1 #detecting and deleting outliers from the  test data
# ----> 2 for i in cnames:
#       3     q75, q25 =np.percentile(test_df.loc[:,i],[75,25])
#       4     iqr  = q75-q25
#       5     min  = q25 - (iqr*1.5)
#
# NameError: name 'cnames' is not defined

# %%
#checking the number of observations dropped
print("Total number of observations dropped in test set:",df_test.shape[0]-test_df.shape[0])
test_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-99845c2f3f01> in <module>
#       1 #checking the number of observations dropped
# ----> 2 print("Total number of observations dropped in test set:",df_test.shape[0]-test_df.shape[0])
#       3 test_df.shape
#
# NameError: name 'df_test' is not defined

# %% [markdown]
# # Feature Selection
# Now lets check the correlation between the features in train set

# %%
df_corr= train_df.loc[:,cnames]
f,ax= plt.subplots(figsize=(7,5))
corr= df_corr.corr()
sns.heatmap(corr,mask= np.zeros_like(corr,dtype= np.bool),cmap= sns.diverging_palette(220,10,as_cmap= True),square= True,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-4be1a88d7001> in <module>
# ----> 1 df_corr= train_df.loc[:,cnames]
#       2 f,ax= plt.subplots(figsize=(7,5))
#       3 corr= df_corr.corr()
#       4 sns.heatmap(corr,mask= np.zeros_like(corr,dtype= np.bool),cmap= sns.diverging_palette(220,10,as_cmap= True),square= True,ax=ax)
#
# NameError: name 'cnames' is not defined

# %%
#copying data
data_Train =train_df.copy()
data_Test  =test_df.copy()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-46-6951308657e4> in <module>
#       1 #copying data
# ----> 2 data_Train =train_df.copy()
#       3 data_Test  =test_df.copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5994         dtype: object
#    5995         """
# -> 5996         data = self._data.copy(deep=deep)
#    5997         return self._constructor(data).__finalize__(self)
#    5998
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     770         values = self.values
#     771         if deep:
# --> 772             values = values.copy()
#     773         return self.make_block_same_class(values, ndim=self.ndim)
#     774
#
# MemoryError:

# %% [markdown]
# # Feature Scaling
# While observing the distributions there were slight variations here and there and even in description of the dataset standard deviation of the variables is high. So, before going for modelling lets normalize the data.

# %%
#Normalization of train set
for i in cnames:
    train_df[i]=(train_df[i]-train_df[i].min())/(train_df[i].max()-train_df[i].min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-0fb65b15eabb> in <module>
#       1 #Normalization of train set
# ----> 2 for i in cnames:
#       3     train_df[i]=(train_df[i]-train_df[i].min())/(train_df[i].max()-train_df[i].min())
#
# NameError: name 'cnames' is not defined

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
#Normalization of test set
for i in cnames:
    test_df[i]=(test_df[i]-test_df[i].min())/(test_df[i].max()-test_df[i].min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-6e4c8b641a02> in <module>
#       1 #Normalization of test set
# ----> 2 for i in cnames:
#       3     test_df[i]=(test_df[i]-test_df[i].min())/(test_df[i].max()-test_df[i].min())
#
# NameError: name 'cnames' is not defined

# %%
test_df.head()
# Out:
#   ID_code    var_0    var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  test_0  11.0656   7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493
# 1  test_1   8.5304   1.2543  11.3047  5.1858   9.1974 -4.0117  6.0196
# 2  test_2   5.4827 -10.3581  10.1407  7.0479  10.2628  9.8052  4.8950
# 3  test_3   8.5374  -1.3222  12.0220  6.5749   8.8458  3.1744  4.9397
# 4  test_4  11.7058  -0.1327  14.1295  7.7506   9.1035 -8.5848  6.8595
#
#      var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112   2.4669
# 1  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282  15.5765   0.4773
# 2  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800  12.9813   2.1281
# 3  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813  15.1874   3.1656
# 4  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778  19.5542  -0.2860
#
#    var_196  var_197  var_198  var_199
# 0   4.3654  10.7200  15.4722  -8.7197
# 1  -1.4852   9.8714  19.1293 -20.9760
# 2  -7.1086   7.0618  19.8956 -23.1794
# 3   3.9567   9.2295  13.0168  -4.2108
# 4  -5.1612   7.2882  13.9260  -9.1846
#
# [5 rows x 201 columns]

# %%
#copying the normalised data
train_N = train_df.copy()
test_N  = test_df.copy()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-51-aa0d0af68551> in <module>
#       1 #copying the normalised data
# ----> 2 train_N = train_df.copy()
#       3 test_N  = test_df.copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5994         dtype: object
#    5995         """
# -> 5996         data = self._data.copy(deep=deep)
#    5997         return self._constructor(data).__finalize__(self)
#    5998
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     786         else:
#     787             new_axes = list(self.axes)
# --> 788         return self.apply("copy", axes=new_axes, deep=deep, do_integrity_check=False)
#     789
#     790     def as_array(self, transpose=False, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     770         values = self.values
#     771         if deep:
# --> 772             values = values.copy()
#     773         return self.make_block_same_class(values, ndim=self.ndim)
#     774
#
# MemoryError:

# %%
#dropping ID_code variable from both train and test sets
train_df=train_df.drop(columns='ID_code',axis=1)
test_df =test_df.drop(columns='ID_code',axis=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-52-ca6b3471737b> in <module>
#       1 #dropping ID_code variable from both train and test sets
# ----> 2 train_df=train_df.drop(columns='ID_code',axis=1)
#       3 test_df =test_df.drop(columns='ID_code',axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945             else:
#    3946                 new_axis = axis.drop(labels, errors=errors)
# -> 3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#    3949         # Case for non-unique axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3959         kwargs.pop("axis", None)
#    3960         kwargs.pop("labels", None)
# -> 3961         return super().reindex(**kwargs)
#    3962
#    3963     def drop(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3841         if columns is not None:
#    3842             frame = frame._reindex_columns(
# -> 3843                 columns, method, copy, level, fill_value, limit, tolerance
#    3844             )
#    3845
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3889             copy=copy,
#    3890             fill_value=fill_value,
# -> 3891             allow_dups=False,
#    3892         )
#    3893
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1355                             axis=0,
#    1356                             new_mgr_locs=mgr_locs,
# -> 1357                             fill_tuple=None,
#    1358                         )
#    1359                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1714             out = np.empty(out_shape, dtype=dtype, order="F")
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#    1718     func = _get_take_nd_function(
#
# MemoryError:

# %% [markdown]
# # Resampling

# %%
## Get the YES and the NO from the target 

YES = train_df[train_df['target']==1]

NO  = train_df[train_df['target']==0]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-53-f5b32756feaf> in <module>
#       3 YES = train_df[train_df['target']==1]
#       4
# ----> 5 NO  = train_df[train_df['target']==0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2969         # Do we have a (boolean) 1d indexer?
#    2970         if com.is_bool_indexer(key):
# -> 2971             return self._getitem_bool_array(key)
#    2972
#    2973         # We are left with two options: a single key, and a collection of keys,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3023         key = check_bool_indexer(self.index, key)
#    3024         indexer = key.nonzero()[0]
# -> 3025         return self.take(indexer, axis=0)
#    3026
#    3027     def _getitem_multilevel(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3602
#    3603         new_data = self._data.take(
# -> 3604             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3605         )
#    3606         result = self._constructor(new_data).__finalize__(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1395         new_labels = self.axes[axis].take(indexer)
#    1396         return self.reindex_indexer(
# -> 1397             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1398         )
#    1399
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1265                     ),
#    1266                 )
# -> 1267                 for blk in self.blocks
#    1268             ]
#    1269
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1312
#    1313         new_values = algos.take_nd(
# -> 1314             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1315         )
#    1316
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1714             out = np.empty(out_shape, dtype=dtype, order="F")
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#    1718     func = _get_take_nd_function(
#
# MemoryError:

# %%
print(YES.shape,NO.shape)

# %%
#Separating the dependent and independent variables
y =train_df['target']
X =train_df.drop(['target'],axis=1)

# %%
# Random Over sampler to handle the imbalanced dataset
from imblearn.over_sampling import RandomOverSampler

# %%
os = RandomOverSampler(ratio=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-3c467c8b7344> in <module>
# ----> 1 os = RandomOverSampler(ratio=1)
#
# NameError: name 'RandomOverSampler' is not defined

# %%
X_res, Y_res = os.fit_sample(X,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-cac9907ec5b2> in <module>
# ----> 1 X_res, Y_res = os.fit_sample(X,y)
#
# AttributeError: module 'os' has no attribute 'fit_sample'

# %%
X_res.shape,Y_res.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-ee70e3cde709> in <module>
# ----> 1 X_res.shape,Y_res.shape
#
# NameError: name 'X_res' is not defined

# %%
#checking the data distribution in target column
sns.set(style='whitegrid')
sns.countplot(Y_res, palette='Set1')
plt.title("Distribution in Target Variable ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-8a33e2349ae0> in <module>
#       1 #checking the data distribution in target column
#       2 sns.set(style='whitegrid')
# ----> 3 sns.countplot(Y_res, palette='Set1')
#       4 plt.title("Distribution in Target Variable ")
#
# NameError: name 'Y_res' is not defined

# %% [markdown]
# Now we can see that we have a balanced data set after performing over sampling on target column.

# %% [markdown]
# # Modelling

# %%
#importing packages 
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import confusion_matrix

# %%
#dividing data_set into train & test
X_train, X_test, Y_train, Y_test= train_test_split(X_res, Y_res, test_size=0.2, random_state=82)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-1908dcc86a99> in <module>
#       1 #dividing data_set into train & test
# ----> 2 X_train, X_test, Y_train, Y_test= train_test_split(X_res, Y_res, test_size=0.2, random_state=82)
#
# NameError: name 'X_res' is not defined

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)

# %% [markdown]
# # Logistic Regression

# %%
#fitting the model
logit = sm.Logit(Y_train,X_train).fit()
logit.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-764db5a5fcde> in <module>
#       1 #fitting the model
# ----> 2 logit = sm.Logit(Y_train,X_train).fit()
#       3 logit.summary()
#
# NameError: name 'Y_train' is not defined

# %%
#predicting the model
logit_predict = logit.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-af13fe74be26> in <module>
#       1 #predicting the model
# ----> 2 logit_predict = logit.predict(X_test)
#
# NameError: name 'logit' is not defined

# %%
y_predict=logit_predict.round()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-9196d5305936> in <module>
# ----> 1 y_predict=logit_predict.round()
#
# NameError: name 'logit_predict' is not defined

# %%
#from the metrics
confusion_matrix(Y_test,y_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-5950c6cf225e> in <module>
#       1 #from the metrics
# ----> 2 confusion_matrix(Y_test,y_predict)
#
# NameError: name 'Y_test' is not defined

# %% [markdown]
# # Logistic Regression Metrics

# %%
#creating confusion matrix
CM =pd.crosstab(Y_test,y_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-b08a29f433e8> in <module>
#       1 #creating confusion matrix
# ----> 2 CM =pd.crosstab(Y_test,y_predict)
#
# NameError: name 'Y_test' is not defined

# %%
#let us save TP, TN, FP, FN
TP = CM.iloc[0,0]
FP = CM.iloc[1,0]
TN = CM.iloc[1,1]
FN = CM.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-90dd9285d642> in <module>
#       1 #let us save TP, TN, FP, FN
# ----> 2 TP = CM.iloc[0,0]
#       3 FP = CM.iloc[1,0]
#       4 TN = CM.iloc[1,1]
#       5 FN = CM.iloc[0,1]
#
# NameError: name 'CM' is not defined

# %%
#check accuracy of model
accuracy_score = ((TP+TN)/(TP+TN+FP+FN))*100
print('accuracy score : {} %'.format(accuracy_score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e0de70db6c70> in <module>
#       1 #check accuracy of model
# ----> 2 accuracy_score = ((TP+TN)/(TP+TN+FP+FN))*100
#       3 print('accuracy score : {} %'.format(accuracy_score))
#
# NameError: name 'TP' is not defined

# %%
#check recall of the model
recall = ((TP)/(TP+FN))*100
print('Recall score: {} %'.format(recall))
specificity = ((TN)/(TN+FP))*100
print('Specificity: {} %'.format(specificity))
false_positive = ((FP)/(FP+TN))*100
print('False +ve: {} %'.format(false_positive))
false_neg = ((FN)/(FN+TP))*100
print('False -ve: {} %'.format(false_neg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-f2d1c5409b7f> in <module>
#       1 #check recall of the model
# ----> 2 recall = ((TP)/(TP+FN))*100
#       3 print('Recall score: {} %'.format(recall))
#       4 specificity = ((TN)/(TN+FP))*100
#       5 print('Specificity: {} %'.format(specificity))
#
# NameError: name 'TP' is not defined

# %%
#importing metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %%
print("Precision score : {} %".format(precision_score(Y_test,y_predict)*100))
print("Recall score : {} %".format(recall_score(Y_test,y_predict)*100))
print("AUC_score is {}%".format(roc_auc_score(Y_test,y_predict)*100))
print("Accuracy is {}%".format(accuracy_score(Y_test,y_predict)*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-95cd1947c77d> in <module>
# ----> 1 print("Precision score : {} %".format(precision_score(Y_test,y_predict)*100))
#       2 print("Recall score : {} %".format(recall_score(Y_test,y_predict)*100))
#       3 print("AUC_score is {}%".format(roc_auc_score(Y_test,y_predict)*100))
#       4 print("Accuracy is {}%".format(accuracy_score(Y_test,y_predict)*100))
#
# NameError: name 'Y_test' is not defined

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB_model = GaussianNB().fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-4f487338f817> in <module>
# ----> 1 NB_model = GaussianNB().fit(X_train,Y_train)
#
# NameError: name 'X_train' is not defined

# %%
NB_pred = NB_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-1907e5d8a21d> in <module>
# ----> 1 NB_pred = NB_model.predict(X_test)
#
# NameError: name 'NB_model' is not defined

# %%
confusion_matrix(Y_test,NB_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-caa9e126ea08> in <module>
# ----> 1 confusion_matrix(Y_test,NB_pred)
#
# NameError: name 'Y_test' is not defined

# %% [markdown]
# # Naive Bayes Metrics

# %%
#creating confusion matrix
CM =pd.crosstab(Y_test,NB_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-8f5a12779001> in <module>
#       1 #creating confusion matrix
# ----> 2 CM =pd.crosstab(Y_test,NB_pred)
#
# NameError: name 'Y_test' is not defined

# %%
#let us save TP, TN, FP, FN
TP = CM.iloc[0,0]
FP = CM.iloc[1,0]
TN = CM.iloc[1,1]
FN = CM.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-90dd9285d642> in <module>
#       1 #let us save TP, TN, FP, FN
# ----> 2 TP = CM.iloc[0,0]
#       3 FP = CM.iloc[1,0]
#       4 TN = CM.iloc[1,1]
#       5 FN = CM.iloc[0,1]
#
# NameError: name 'CM' is not defined

# %%
#check recall of the model
recall = ((TP)/(TP+FN))*100
print('Recall score: {} %'.format(recall))
specificity = ((TN)/(TN+FP))*100
print('Specificity: {} %'.format(specificity))
false_positive = ((FP)/(FP+TN))*100
print('False +ve: {} %'.format(false_positive))
false_neg = ((FN)/(FN+TP))*100
print('False -ve: {} %'.format(false_neg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f2d1c5409b7f> in <module>
#       1 #check recall of the model
# ----> 2 recall = ((TP)/(TP+FN))*100
#       3 print('Recall score: {} %'.format(recall))
#       4 specificity = ((TN)/(TN+FP))*100
#       5 print('Specificity: {} %'.format(specificity))
#
# NameError: name 'TP' is not defined

# %%
print("Precision score : {} %".format(precision_score(Y_test,NB_pred)*100))
print("Recall score : {} %".format(recall_score(Y_test,NB_pred)*100))
print("AUC_score is {}%".format(roc_auc_score(Y_test,NB_pred)*100))
print("Accuracy is {}%".format(accuracy_score(Y_test,NB_pred)*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-dd0d2279a7f6> in <module>
# ----> 1 print("Precision score : {} %".format(precision_score(Y_test,NB_pred)*100))
#       2 print("Recall score : {} %".format(recall_score(Y_test,NB_pred)*100))
#       3 print("AUC_score is {}%".format(roc_auc_score(Y_test,NB_pred)*100))
#       4 print("Accuracy is {}%".format(accuracy_score(Y_test,NB_pred)*100))
#
# NameError: name 'Y_test' is not defined

# %%
#converting Numerics to strings 
y=pd.DataFrame(Y_res)
y=y.replace(0,"NO")
y=y.replace(1,'YES')
Y=y.values.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-75c7189e1ea2> in <module>
#       1 #converting Numerics to strings
# ----> 2 y=pd.DataFrame(Y_res)
#       3 y=y.replace(0,"NO")
#       4 y=y.replace(1,'YES')
#       5 Y=y.values.ravel()
#
# NameError: name 'Y_res' is not defined

# %%
#dividing data_set into train & test
x_train, x_test, y_train, y_test= train_test_split(X_res, Y, test_size=0.2, random_state=82)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-4d09459a26a1> in <module>
#       1 #dividing data_set into train & test
# ----> 2 x_train, x_test, y_train, y_test= train_test_split(X_res, Y, test_size=0.2, random_state=82)
#
# NameError: name 'X_res' is not defined

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-59db756b694a> in <module>
# ----> 1 print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#fitting the model
RF_model = RandomForestClassifier(n_estimators=10).fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-90baed2a9ccb> in <module>
#       1 #fitting the model
# ----> 2 RF_model = RandomForestClassifier(n_estimators=10).fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
#predicting
RF_pred = RF_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-a212144c4942> in <module>
#       1 #predicting
# ----> 2 RF_pred = RF_model.predict(x_test)
#
# NameError: name 'RF_model' is not defined

# %%
confusion_matrix(y_test,RF_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-3b5270a4ba6a> in <module>
# ----> 1 confusion_matrix(y_test,RF_pred)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# # Random Forest Metrics

# %%
#creating confusion matrix
CM =pd.crosstab(y_test,RF_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-ea61c065605a> in <module>
#       1 #creating confusion matrix
# ----> 2 CM =pd.crosstab(y_test,RF_pred)
#
# NameError: name 'y_test' is not defined

# %%
#let us save TP, TN, FP, FN
TP = CM.iloc[0,0]
FP = CM.iloc[1,0]
TN = CM.iloc[1,1]
FN = CM.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-90dd9285d642> in <module>
#       1 #let us save TP, TN, FP, FN
# ----> 2 TP = CM.iloc[0,0]
#       3 FP = CM.iloc[1,0]
#       4 TN = CM.iloc[1,1]
#       5 FN = CM.iloc[0,1]
#
# NameError: name 'CM' is not defined

# %%
#check recall of the model
recall = ((TP)/(TP+FN))*100
print('Recall score: {} %'.format(recall))
specificity = ((TN)/(TN+FP))*100
print('Specificity: {} %'.format(specificity))
false_positive = ((FP)/(FP+TN))*100
print('False +ve: {} %'.format(false_positive))
false_neg = ((FN)/(FN+TP))*100
print('False -ve: {} %'.format(false_neg))
precision = ((TP)/(TP+FP))*100
print('Precision : {}%'.format(precision))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-9aa457cb14c7> in <module>
#       1 #check recall of the model
# ----> 2 recall = ((TP)/(TP+FN))*100
#       3 print('Recall score: {} %'.format(recall))
#       4 specificity = ((TN)/(TN+FP))*100
#       5 print('Specificity: {} %'.format(specificity))
#
# NameError: name 'TP' is not defined

# %%
print("Accuracy is {}%".format(((TP+TN)/(TN+FN+TP+FP))*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-95cfb189b381> in <module>
# ----> 1 print("Accuracy is {}%".format(((TP+TN)/(TN+FN+TP+FP))*100))
#
# NameError: name 'TP' is not defined

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree

# %%
DT_model = tree.DecisionTreeClassifier(criterion='entropy').fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-7adf6c0430c2> in <module>
# ----> 1 DT_model = tree.DecisionTreeClassifier(criterion='entropy').fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
DT_pred = DT_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-129614cc935a> in <module>
# ----> 1 DT_pred = DT_model.predict(x_test)
#
# NameError: name 'DT_model' is not defined

# %%
confusion_matrix(y_test,RF_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-3b5270a4ba6a> in <module>
# ----> 1 confusion_matrix(y_test,RF_pred)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# # Desicion Tree Metrics

# %%
#creating confusion matrix
CM =pd.crosstab(y_test,RF_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-ea61c065605a> in <module>
#       1 #creating confusion matrix
# ----> 2 CM =pd.crosstab(y_test,RF_pred)
#
# NameError: name 'y_test' is not defined

# %%
#let us save TP, TN, FP, FN
TP = CM.iloc[0,0]
FP = CM.iloc[1,0]
TN = CM.iloc[1,1]
FN = CM.iloc[0,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-90dd9285d642> in <module>
#       1 #let us save TP, TN, FP, FN
# ----> 2 TP = CM.iloc[0,0]
#       3 FP = CM.iloc[1,0]
#       4 TN = CM.iloc[1,1]
#       5 FN = CM.iloc[0,1]
#
# NameError: name 'CM' is not defined

# %%
#check recall of the model
recall = ((TP)/(TP+FN))*100
print('Recall score: {} %'.format(recall))
specificity = ((TN)/(TN+FP))*100
print('Specificity: {} %'.format(specificity))
false_positive = ((FP)/(FP+TN))*100
print('False +ve: {} %'.format(false_positive))
false_neg = ((FN)/(FN+TP))*100
print('False -ve: {} %'.format(false_neg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-f2d1c5409b7f> in <module>
#       1 #check recall of the model
# ----> 2 recall = ((TP)/(TP+FN))*100
#       3 print('Recall score: {} %'.format(recall))
#       4 specificity = ((TN)/(TN+FP))*100
#       5 print('Specificity: {} %'.format(specificity))
#
# NameError: name 'TP' is not defined

# %%
print("Accuracy is {}%".format(((TP+TN)/(TN+FN+TP+FP))*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-95cfb189b381> in <module>
# ----> 1 print("Accuracy is {}%".format(((TP+TN)/(TN+FN+TP+FP))*100))
#
# NameError: name 'TP' is not defined

# %% [markdown]
# # Predicting on Test data

# %%
#Predicting on test data
Predictions = RF_model.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-ea90b0b64a2a> in <module>
#       1 #Predicting on test data
# ----> 2 Predictions = RF_model.predict(test_df)
#
# NameError: name 'RF_model' is not defined

# %%
#adding the predictions to test dataset
test_N['target']=Predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-c3077831f7f7> in <module>
#       1 #adding the predictions to test dataset
# ----> 2 test_N['target']=Predictions
#
# NameError: name 'Predictions' is not defined

# %%
test_N.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-b89d8ecf6e9f> in <module>
# ----> 1 test_N.tail(10)
#
# NameError: name 'test_N' is not defined

# %%
#saving the data in csv
test_N.to_csv("E:\\Data Science santander\\test_pred.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-0e587a78fe98> in <module>
#       1 #saving the data in csv
# ----> 2 test_N.to_csv("E:\\Data Science santander\\test_pred.csv")
#
# NameError: name 'test_N' is not defined

# %% [markdown]
# # Deployment

# %%
import pickle
import json
import requests

# %%
pickle.dump(RF_model, open('model.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-bf1f6c8a5aa5> in <module>
# ----> 1 pickle.dump(RF_model, open('model.pkl','wb'))
#
# NameError: name 'RF_model' is not defined

# %%
model = pickle.load(open('model.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-104-88b61be17d4c> in <module>
# ----> 1 model = pickle.load(open('model.pkl','rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'

# %%
from flask import Flask, request, jsonify
import pickle

app = Flask(__name__)

# Load the model
model = pickle.load(open('model.pkl','rb'))

@app.route('/api',methods=['POST'])
def predict():
    # Get the data from the POST request.
    data = request.get_json(force=True)

    # Make prediction using model loaded from disk as per the data.
    prediction = model.predict([[np.array(data['var_0'])]])

    # Take the first value of prediction
    output = prediction[0]

    return jsonify(output)

if __name__ == '__main__':
    app.run(debug=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-105-3c383991eb23> in <module>
#       5
#       6 # Load the model
# ----> 7 model = pickle.load(open('model.pkl','rb'))
#       8
#       9 @app.route('/api',methods=['POST'])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'

# %%
import requests

url = 'http://localhost:8888/api'

r = requests.post(url,json={'var_0':0.133981,})
print(r.json())
# Out:
# {'message': "'_xsrf' argument missing from POST", 'reason': None}
